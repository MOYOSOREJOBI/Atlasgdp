# %% [markdown]
# # 01 Baseline World Bank Panel
#
# This notebook mirrors the baseline panel logic used in the ATLAS-GDP scripts.
# It preserves the offline fallback concept and artifact bundling approach.
